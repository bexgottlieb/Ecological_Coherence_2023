# %% [markdown]
# # Adequacy - MPA Size 4.1

# %% [markdown]
# ### Import libraries and set up environment

# %%
import os
import sys

import pandas as pd
print(pd.__version__)

import numpy as np
print(np.__version__)

import arcpy

import arcgis
print(arcgis.__version__)

from arcgis.gis import GIS
from arcgis.mapping import WebMap
from arcgis.features import FeatureLayer
# Out:
# 1.4.4
# 1.20.1
# 2.1.0.2

# %%
# Set the workspace and environment settings

arcpy.env.workspace = r"F:\Bex\ArcGIS\Ecological_coherence_2023\Ecological_coherence_2023.gdb"
arcpy.env.overwriteOutput = True

# %% [markdown]
# #### 4.1 MPA Size

# %%
# Intersect the MPAs with the study area

in_feature_1 = "WDPA_MPA"
in_feature_2 = "Caribbean_detailed_subregions_mol"
out_feature = "\\MPA_Carib_int_Adq_4_1"
output_gdb = r"F:\Bex\ArcGIS\Ecological_coherence_2023\Ecological_coherence_2023.gdb"

arcpy.analysis.PairwiseIntersect(
    in_features=[in_feature_1,in_feature_2],
    out_feature_class= output_gdb + out_feature,
    join_attributes="ALL",
    cluster_tolerance=None,
)
# Out:
# <Result 'F:\\Bex\\ArcGIS\\Ecological_coherence_2023\\Ecological_coherence_2023.gdb\\MPA_Carib_int_Adq_4_1'>

# %%
# Repair geoemtry on the intersect, calculate area, and export to excel

# Set a folder to store the output tables
table_outputs_folder = r"F:\Bex\ArcGIS\Ecological_coherence_2023\Tables\Adequacy"

in_feature = "MPA_Carib_int_Adq_4_1"
output_gdb = r"F:\Bex\ArcGIS\Ecological_coherence_2023\Ecological_coherence_2023.gdb"

def repair_geo_area_export():
    #repair geometry
    arcpy.management.RepairGeometry(
        in_features= in_feature,
        delete_null="DELETE_NULL",
        validation_method="OGC"
    )
            
    # insert "area" field (double) and calculate area in km2 in Mollweide
    arcpy.management.CalculateGeometryAttributes(
        in_features= in_feature,
        geometry_property="area AREA",
        length_unit="",
        area_unit="SQUARE_KILOMETERS",
        coordinate_system='PROJCS["World_Mollweide",GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Mollweide"],PARAMETER["False_Easting",0.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",0.0],UNIT["Meter",1.0]]',
        coordinate_format="SAME_AS_INPUT"
    )
    
    # Export tables to excel
    # Not sure why I had to use the following two lines instead of just using the TableToExcel expression, but I did
    excel_filename = in_feature + ".xlsx"
    excel_filepath = os.path.join(table_outputs_folder, excel_filename)  # Build the full file path

    arcpy.conversion.TableToExcel(
        Input_Table= in_feature,
        Output_Excel_File= excel_filepath,
        Use_field_alias_as_column_header="NAME",
        Use_domain_and_subtype_description="CODE"
    )
    
repair_geo_area_export()

# %%
# Convert the output features to a Pandas DataFrame
df_MPA = pd.DataFrame.spatial.from_featureclass("MPA_Carib_int_Adq_4_1")

# %%
# Display the DataFrame
df_MPA.head()
# Out:
#    OBJECTID  FID_WDPA_MPA       WDPAID   WDPA_PID PA_DEF  \
# 0         1             1  555637442.0  555637442      1
# 1         2             2  555705843.0  555705843      1
# 2         3             3      14075.0      14075      1
# 3         4             4      32636.0      32636      1
# 4         5             5      32638.0      32638      1
#
#                                          NAME  \
# 0  Sombrero Island Nature Reserve Marine Park
# 1                                  Little Bay
# 2          Shoal Bay and Island Harbour Reefs
# 3     Prickly Pear Cays and Seal Island Reefs
# 4                                  Dog Island
#
#                                     ORIG_NAME  \
# 0  Sombrero Island Nature Reserve Marine Park
# 1                                  Little Bay
# 2          Shoal Bay and Island Harbour Reefs
# 3     Prickly Pear Cays and Seal Island Reefs
# 4                                  Dog Island
#
#                                               DESIG  \
# 0  Ramsar Site, Wetland of International Importance
# 1                                       Marine Park
# 2                                       Marine Park
# 3                                       Marine Park
# 4                                       Marine Park
#
#                                           DESIG_ENG     DESIG_TYPE  ... ISO3  \
# 0  Ramsar Site, Wetland of International Importance  International  ...  AIA
# 1                                       Marine Park       National  ...  AIA
# 2                                       Marine Park       National  ...  AIA
# 3                                       Marine Park       National  ...  AIA
# 4                                       Marine Park       National  ...  AIA
#
#   marine_area_ha total_area_ha  Percent_marine_area  MPA  \
# 0     994.880711   1055.585834            94.249153  yes
# 1      43.801052     70.984313            61.705256  yes
# 2    1199.883572   1787.212832            67.137139  yes
# 3    2938.725702   3076.791859            95.512659  yes
# 4     625.830917    765.341622            81.771447  yes
#
#    FID_Caribbean_detailed_subregions_mol  ORIG_FID       Area  \
# 0                                      8         2   9.948807
# 1                                      8         2   0.438011
# 2                                      8         2  11.998836
# 3                                      8         2  29.387257
# 4                                      8         2   6.258309
#
#            Subregion                                              SHAPE
# 0  Eastern Caribbean  {"hasZ": true, "rings": [[[-6150002.3972, 2283...
# 1  Eastern Caribbean  {"hasZ": true, "rings": [[[-6123424.997400001,...
# 2  Eastern Caribbean  {"hasZ": true, "rings": [[[-6114933.1085, 2244...
# 3  Eastern Caribbean  {"hasZ": true, "rings": [[[-6132163.2213, 2245...
# 4  Eastern Caribbean  {"hasZ": true, "rings": [[[-6141845.469699999,...
#
# [5 rows x 39 columns]

# %%
# Make sure PAs with multiple parcels are only counted once and the areas of the parcels are summed

# group by WDPAID and sum the GIS_AREAs of rows with the same WDPAID (to get a total size of the site)
df_MPA["AREA_SUM"] = df_MPA.groupby("WDPAID")["Area"].transform("sum")
print(df_MPA)

#sort by the Area field, in descending order
df_MPA = df_MPA.sort_values(by = "Area", ascending = False)

#drop rows that have duplicate WDPAIDs, keeping the first duplicate (which is the one with the largest GIS_AREA)
df_MPA_NoDup = df_MPA.drop_duplicates("WDPAID", keep = "first")
print(df_MPA_NoDup)
# Out:
#      OBJECTID  FID_WDPA_MPA       WDPAID   WDPA_PID PA_DEF  \
# 0           1             1  555637442.0  555637442      1
# 1           2             2  555705843.0  555705843      1
# 2           3             3      14075.0      14075      1
# 3           4             4      32636.0      32636      1
# 4           5             5      32638.0      32638      1
# ..        ...           ...          ...        ...    ...
# 857       858           737     101430.0     101430      1
# 858       859           738     342346.0     342346      1
# 859       860           739      71021.0      71021      1
# 860       861           740      20134.0      20134      1
# 861       862           748     167051.0     167051      1
#
#                                            NAME  \
# 0    Sombrero Island Nature Reserve Marine Park
# 1                                    Little Bay
# 2            Shoal Bay and Island Harbour Reefs
# 3       Prickly Pear Cays and Seal Island Reefs
# 4                                    Dog Island
# ..                                          ...
# 857                          Laguna de Términos
# 858          Laguna Madre y Delta del Río Bravo
# 859                                Ría Celestún
# 860                          Pantanos de Centla
# 861                                 Los Tuxtlas
#
#                                       ORIG_NAME  \
# 0    Sombrero Island Nature Reserve Marine Park
# 1                                    Little Bay
# 2            Shoal Bay and Island Harbour Reefs
# 3       Prickly Pear Cays and Seal Island Reefs
# 4                                    Dog Island
# ..                                          ...
# 857                          Laguna de Términos
# 858          Laguna Madre y Delta del Río Bravo
# 859                                Ría Celestún
# 860                          Pantanos de Centla
# 861                                 Los Tuxtlas
#
#                                                 DESIG  \
# 0    Ramsar Site, Wetland of International Importance
# 1                                         Marine Park
# 2                                         Marine Park
# 3                                         Marine Park
# 4                                         Marine Park
# ..                                                ...
# 857               Área de Protección de Flora y Fauna
# 858               Área de Protección de Flora y Fauna
# 859                            Reserva de la Biósfera
# 860                            Reserva de la Biósfera
# 861                            Reserva de la Biósfera
#
#                                             DESIG_ENG     DESIG_TYPE  ...  \
# 0    Ramsar Site, Wetland of International Importance  International  ...
# 1                                         Marine Park       National  ...
# 2                                         Marine Park       National  ...
# 3                                         Marine Park       National  ...
# 4                                         Marine Park       National  ...
# ..                                                ...            ...  ...
# 857                   Flora and Fauna Protection Area       National  ...
# 858                   Flora and Fauna Protection Area       National  ...
# 859                                 Biosphere Reserve       National  ...
# 860                                 Biosphere Reserve       National  ...
# 861                                 Biosphere Reserve       National  ...
#
#     marine_area_ha  total_area_ha Percent_marine_area  MPA  \
# 0       994.880711    1055.585834           94.249153  yes
# 1        43.801052      70.984313           61.705256  yes
# 2      1199.883572    1787.212832           67.137139  yes
# 3      2938.725702    3076.791859           95.512659  yes
# 4       625.830917     765.341622           81.771447  yes
# ..             ...            ...                 ...  ...
# 857  304471.789368  710195.947572           42.871519  yes
# 858  197528.883617  574232.657227           34.398755  yes
# 859   21134.277538   81768.587598           25.846451  yes
# 860     143.419690  305237.960793            0.046986  yes
# 861     869.268639  157068.427066            0.553433  yes
#
#      FID_Caribbean_detailed_subregions_mol  ORIG_FID         Area  \
# 0                                        8         2     9.948807
# 1                                        8         2     0.438011
# 2                                        8         2    11.998836
# 3                                        8         2    29.387257
# 4                                        8         2     6.258309
# ..                                     ...       ...          ...
# 857                                      2         2  3044.717894
# 858                                      2         2  1975.288836
# 859                                      2         2   211.342775
# 860                                      2         2     1.434197
# 861                                      2         2     8.692686
#
#              Subregion                                              SHAPE  \
# 0    Eastern Caribbean  {"hasZ": true, "rings": [[[-6150002.3972, 2283...
# 1    Eastern Caribbean  {"hasZ": true, "rings": [[[-6123424.997400001,...
# 2    Eastern Caribbean  {"hasZ": true, "rings": [[[-6114933.1085, 2244...
# 3    Eastern Caribbean  {"hasZ": true, "rings": [[[-6132163.2213, 2245...
# 4    Eastern Caribbean  {"hasZ": true, "rings": [[[-6141845.469699999,...
# ..                 ...                                                ...
# 857     Gulf of Mexico  {"hasZ": true, "rings": [[[-8963965.7962, 2290...
# 858     Gulf of Mexico  {"hasZ": true, "rings": [[[-9198186.6027, 3053...
# 859     Gulf of Mexico  {"hasZ": true, "rings": [[[-8680491.5619, 2571...
# 860     Gulf of Mexico  {"hasZ": true, "rings": [[[-8986114.1603, 2272...
# 861     Gulf of Mexico  {"hasZ": true, "rings": [[[-9187520.8029, 2253...
#
#         AREA_SUM
# 0       9.948807
# 1       0.438011
# 2      11.998836
# 3      29.387257
# 4       6.258309
# ..           ...
# 857  3044.717894
# 858  1975.288836
# 859   211.342775
# 860     1.434197
# 861     8.692686
#
# [862 rows x 40 columns]
#      OBJECTID  FID_WDPA_MPA       WDPAID   WDPA_PID PA_DEF  \
# 479       480            64  555587040.0  555587040      1
# 704       705           413  555636411.0  555636411      1
# 705       706           177  555624229.0  555624229      1
# 286       287           747  555624306.0  555624306      1
# 187       188           776  555597297.0  555597297      1
# ..        ...           ...          ...        ...    ...
# 85         86           808     392042.0     392042      1
# 370       371           609  555661938.0  555661938      1
# 185       186           774     330640.0     330640      1
# 405       406            78      12792.0      12792      1
# 52         53           795     392099.0     392099      1
#
#                                                   NAME  \
# 479                                               Agoa
# 704  Area Marina Protegida de la Reserva de Biosfer...
# 705                                          Seaflower
# 286                                    Caribe Mexicano
# 187                                         Martinique
# ..                                                 ...
# 85                        Cul De Sac De Petite Grenade
# 370  Rookery Bay National Estuarine Sanctuary Macro...
# 185                                       Ilet Thierry
# 405                    Dennis Point Replenishment Zone
# 52                         Pointe De Miquelon Gros Cap
#
#                                              ORIG_NAME  \
# 479                                               Agoa
# 704  Area Marina Protegida de la Reserva de Biosfer...
# 705                                          Seaflower
# 286                                    Caribe Mexicano
# 187                                         Martinique
# ..                                                 ...
# 85                        Cul De Sac De Petite Grenade
# 370  Rookery Bay National Estuarine Sanctuary Macro...
# 185                                       Ilet Thierry
# 405   Salt Water Point - Beach Point RpZ (Cayman Brac)
# 52                         Pointe De Miquelon Gros Cap
#
#                                                DESIG  \
# 479  Specially Protected Area (Cartagena Convention)
# 704         Distritos Nacionales de Manejo Integrado
# 705  Specially Protected Area (Cartagena Convention)
# 286                           Reserva de la Biósfera
# 187                               Parc naturel marin
# ..                                               ...
# 85   Terrain acquis par le Conservatoire du Littoral
# 370                                        Sanctuary
# 185                  Arrêté de protection de biotope
# 405                               Replenishment Zone
# 52   Terrain acquis par le Conservatoire du Littoral
#
#                                              DESIG_ENG DESIG_TYPE  ...  \
# 479    Specially Protected Area (Cartagena Convention)   Regional  ...
# 704           Integrated Management National Districts   National  ...
# 705    Specially Protected Area (Cartagena Convention)   Regional  ...
# 286                                  Biosphere Reserve   National  ...
# 187                                 Marine Nature Park   National  ...
# ..                                                 ...        ...  ...
# 85   Land acquired by Conservatoire du Littoral (na...   National  ...
# 370                                          Sanctuary   National  ...
# 185                           Biotope Protection Order   National  ...
# 405                                 Replenishment Zone   National  ...
# 52   Land acquired by Conservatoire du Littoral (na...   National  ...
#
#     marine_area_ha total_area_ha Percent_marine_area  MPA  \
# 479   1.437766e+07  1.440813e+07           99.788511  yes
# 704   6.114051e+06  6.115056e+06           99.983569  yes
# 705   6.114051e+06  6.115056e+06           99.983569  yes
# 286   5.794426e+06  5.827955e+06           99.424683  yes
# 187   4.771128e+06  4.782198e+06           99.768515  yes
# ..             ...           ...                 ...  ...
# 85    1.144855e+01  3.481789e+01           32.881230  yes
# 370   1.137962e+01  2.577779e+01           44.145058  yes
# 185   1.137937e+01  1.137937e+01          100.000004  yes
# 405   1.136979e+01  2.120527e+01           53.617742  yes
# 52    1.036833e+01  1.036833e+01          100.000000  yes
#
#      FID_Caribbean_detailed_subregions_mol  ORIG_FID           Area  \
# 479                                      8         2  143745.863201
# 704                                     14         2   61140.514474
# 705                                     14         2   61140.514474
# 286                                     16         2   57802.553948
# 187                                      8         2   47711.275315
# ..                                     ...       ...            ...
# 85                                       8         2       0.114485
# 370                                      4         2       0.113796
# 185                                      8         2       0.113794
# 405                                      1         2       0.113698
# 52                                       8         2       0.103683
#
#                   Subregion  \
# 479       Eastern Caribbean
# 704  Southwestern Caribbean
# 705  Southwestern Caribbean
# 286       Western Caribbean
# 187       Eastern Caribbean
# ..                      ...
# 85        Eastern Caribbean
# 370                 Florida
# 185       Eastern Caribbean
# 405        Greater Antilles
# 52        Eastern Caribbean
#
#                                                  SHAPE       AREA_SUM
# 479  {"hasZ": true, "rings": [[[-6025186.444599999,...  143776.586579
# 704  {"hasZ": true, "rings": [[[-7831607.681700001,...   61140.514474
# 705  {"hasZ": true, "rings": [[[-7831607.681700001,...   61140.514474
# 286  {"hasZ": true, "rings": [[[-8323397.442399999,...   57944.257554
# 187  {"hasZ": true, "rings": [[[-5979117.8278, 1775...   47711.275315
# ..                                                 ...            ...
# 85   {"hasZ": true, "rings": [[[-5976607.0045, 1793...       0.114485
# 370  {"hasZ": true, "rings": [[[-7669125.559699999,...       0.113796
# 185  {"hasZ": true, "rings": [[[-5975407.446699999,...       0.113794
# 405  {"hasZ": true, "rings": [[[-7709291.7991, 2416...       0.113698
# 52   {"hasZ": true, "rings": [[[-6032398.3089000005...       0.103683
#
# [846 rows x 40 columns]

# %%
# Filter the results into bins based on MPA area

# Create a list of dictionaries with the results
area_results_dict = [
    {"Bin description": "Total MPA count", "Number of MPAs": df_MPA_NoDup['WDPAID'].nunique()},
    {"Bin description": "Total MPA count with Area < 5 km2", "Number of MPAs": df_MPA_NoDup[df_MPA_NoDup['AREA_SUM'] < 5]['WDPAID'].nunique()},
    {"Bin description": "Total MPA count with Area >= 5 and < 30 km2", "Number of MPAs": df_MPA_NoDup[(df_MPA_NoDup['AREA_SUM'] >= 5) & (df_MPA_NoDup['AREA_SUM'] < 30)]['WDPAID'].nunique()},
    {"Bin description": "Total MPA count with Area >= 30 and < 100 km2", "Number of MPAs": df_MPA_NoDup[(df_MPA_NoDup['AREA_SUM'] >= 30) & (df_MPA_NoDup['AREA_SUM'] < 100)]['WDPAID'].nunique()},
    {"Bin description": "Total MPA count with Area >= 100 km2", "Number of MPAs": df_MPA_NoDup[df_MPA_NoDup['AREA_SUM'] >= 100]['WDPAID'].nunique()}
]

# Create a DataFrame from the list of dictionaries
area_result_df = pd.DataFrame(area_results_dict)

# Print the resulting DataFrame
print(area_result_df)
# Out:
#                                  Bin description  Number of MPAs
# 0                                Total MPA count             846
# 1              Total MPA count with Area < 5 km2             313
# 2    Total MPA count with Area >= 5 and < 30 km2             185
# 3  Total MPA count with Area >= 30 and < 100 km2             119
# 4           Total MPA count with Area >= 100 km2             229

# %%
# Export results sorted by area to excel

table_outputs_folder = r"F:\Bex\ArcGIS\Ecological_coherence_2023\Tables\Adequacy"
table = area_result_df
output_name = "MPA_Carib_int_Adq_4_1_area_results.xlsx"

table.to_excel(os.path.join(table_outputs_folder, output_name))

# %%
# reminder to add a row of total number of WDPAs

# seperate it out by subregion and calculate the percent of MPAs per subregion that are larger tahn 5 km2

# Make pivot table of number of MPAs per subregion
pivot_MPA_subregion = df_MPA_NoDup.pivot_table(
     index = "Subregion",
     values = "WDPAID",
     aggfunc = "count"
).reset_index()
pivot_MPA_subregion.columns = ["Subregion", "Number_MPAs"]
print(pivot_MPA_subregion)

# Make pivot table of number of MPAs greater than 5km2 per subregion

#Filter the data frame
df_MPA_5km = df_MPA_NoDup[df_MPA_NoDup['AREA_SUM'] >5]

#make a pivot table from the filtered df
pivot_MPA_5km = df_MPA_5km.pivot_table(
     index = "Subregion",
     values = "WDPAID",
     aggfunc = "count"
).reset_index()
pivot_MPA_5km.columns = ["Subregion", "Number_MPAs_larger_5km2"]
print(pivot_MPA_5km)

# Merge the pivot tables into a single pivot table. The merge should be based on subregion
size = pd.merge(pivot_MPA_subregion, pivot_MPA_5km, on="Subregion", how="left", validate = "1:1")
print(size)

# Add a row for the total number of unique WDPAIDs with Area > 5
total_MPAs = df_MPA_NoDup['WDPAID'].nunique()
total_MPAs_greater_5_count = df_MPA_NoDup[df_MPA_NoDup['AREA_SUM'] > 5]['WDPAID'].nunique()
total_row = {"Subregion": "Total", "Number_MPAs": total_MPAs, "Number_MPAs_larger_5km2": total_MPAs_greater_5_count}
size = size.append(total_row, ignore_index=True)

#add column for the percent MPAs larger than 5km2 per subregion
size.insert(3, "%MPA_larger_5km2", size["Number_MPAs_larger_5km2"] / size["Number_MPAs"] * 100)
print(size)
# Out:
#                 Subregion  Number_MPAs
# 0                Bahamian           56
# 1       Eastern Caribbean          115
# 2                 Florida          144
# 3        Greater Antilles          202
# 4                 Guianan           29
# 5          Gulf of Mexico          108
# 6      Southern Caribbean           57
# 7  Southwestern Caribbean           49
# 8       Western Caribbean           86
#                 Subregion  Number_MPAs_larger_5km2
# 0                Bahamian                       37
# 1       Eastern Caribbean                       48
# 2                 Florida                       72
# 3        Greater Antilles                      133
# 4                 Guianan                       20
# 5          Gulf of Mexico                       72
# 6      Southern Caribbean                       40
# 7  Southwestern Caribbean                       36
# 8       Western Caribbean                       75
#                 Subregion  Number_MPAs  Number_MPAs_larger_5km2
# 0                Bahamian           56                       37
# 1       Eastern Caribbean          115                       48
# 2                 Florida          144                       72
# 3        Greater Antilles          202                      133
# 4                 Guianan           29                       20
# 5          Gulf of Mexico          108                       72
# 6      Southern Caribbean           57                       40
# 7  Southwestern Caribbean           49                       36
# 8       Western Caribbean           86                       75
#                 Subregion  Number_MPAs  Number_MPAs_larger_5km2  \
# 0                Bahamian           56                       37
# 1       Eastern Caribbean          115                       48
# 2                 Florida          144                       72
# 3        Greater Antilles          202                      133
# 4                 Guianan           29                       20
# 5          Gulf of Mexico          108                       72
# 6      Southern Caribbean           57                       40
# 7  Southwestern Caribbean           49                       36
# 8       Western Caribbean           86                       75
# 9                   Total          846                      533
#
#    %MPA_larger_5km2
# 0         66.071429
# 1         41.739130
# 2         50.000000
# 3         65.841584
# 4         68.965517
# 5         66.666667
# 6         70.175439
# 7         73.469388
# 8         87.209302
# 9         63.002364
# C:\Users\bexg\AppData\Local\Temp\ipykernel_8276\2463821511.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   size = size.append(total_row, ignore_index=True)

# %%
# Export subregion results excel

table_outputs_folder = r"F:\Bex\ArcGIS\Ecological_coherence_2023\Tables\Adequacy"
table = size
output_name = "MPA_Carib_int_Adq_4_1_subregion_results_v2.xlsx"

table.to_excel(os.path.join(table_outputs_folder, output_name))
